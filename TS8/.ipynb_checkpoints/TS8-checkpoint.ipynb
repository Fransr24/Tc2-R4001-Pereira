# %% [markdown]
# #  Presentacion de la TS8
# ## Francisco Pereira
#
# ### Ejercicio MAI

# %%
from IPython.display import IFrame
IFrame("Ts8 MAI.pdf", width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="Ts8 MAI.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import matplotlib.pyplot as plt  
import numpy as np  #
import scipy.signal as sig
import splane as tc2

num = np.array([ 1])
den = np.array([ 1, 2, 2, 1])

mi_sos = sig.TransferFunction(num,den)

print (mi_sos)
plt.close('all')
# %matplotlib qt5

tc2.analyze_sys(mi_sos, 'mi SOS')
# Out:
# TransferFunctionContinuous(
# array([1.]),
# array([1., 2., 2., 1.]),
# dt: None
# )

# %% [markdown]
# ### Simulación
# ![image.png](attachment:image.png)
#
# ## Ejercicios Filtros digitales

# %%
from IPython.display import IFrame
IFrame("Ts8 FD.pdf", width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="Ts8 FD.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
