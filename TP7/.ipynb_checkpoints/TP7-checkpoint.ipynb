# %% [markdown]
# #### Teoria de circuitos 2
# #  Presentacion del Trabajo Practico N°7
# ## Grupo 2
# ### Ejercicio 1
#
# ![TP7_1a.jpg](attachment:TP7_1a.jpg)

# %% [markdown]
# ![TP7_1c.jpg](attachment:TP7_1c.jpg)

# %%
from IPython.display import IFrame
IFrame("TP7_1bd.pdf", width=900, height=900)
# Out:
#         <iframe
#             width="900"
#             height="900"
#             src="TP7_1bd.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Ejercicio 2

# %%
from IPython.display import IFrame
IFrame("TP7_2.pdf", width=900, height=900)
# Out:
#         <iframe
#             width="900"
#             height="900"
#             src="TP7_2.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Ejercicio 3

# %%
from IPython.display import IFrame
IFrame("TP7_3.pdf", width=900, height=900)
# Out:
#         <iframe
#             width="900"
#             height="900"
#             src="TP7_3.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ![Circuito_a_transferencia.png](attachment:Circuito_a_transferencia.png)

# %% [markdown]
# ![Circuito_a.png](attachment:Circuito_a.png)

# %% [markdown]
# ![Circuito_b_transferencia.png](attachment:Circuito_b_transferencia.png)

# %% [markdown]
# ![Circuito_b.png](attachment:Circuito_b.png)
#
# ### Ejercicio 4

# %%
from IPython.display import IFrame
IFrame("TP7_4.pdf", width=900, height=900)
# Out:
#         <iframe
#             width="900"
#             height="900"
#             src="TP7_4.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Ejercicio 5

# %%
from IPython.display import IFrame
IFrame("TP7_5.pdf", width=900, height=900)
# Out:
#         <iframe
#             width="900"
#             height="900"
#             src="TP7_5.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
