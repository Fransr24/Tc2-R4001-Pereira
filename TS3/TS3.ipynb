# %% [markdown]
# #  Presentacion de la TS3
# ## Francisco Pereira
#
# ### Ejercicios obligatorios:

# %%
from IPython.display import IFrame
IFrame("Ts3-Final.pdf", width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="Ts3-Final.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import matplotlib.pyplot as plt  
import numpy as np  #
import scipy.signal as sig
from splane import analyze_sys, pretty_print_bicuad_omegayq

num = np.array([1, 0, 0])
num1 = np.array([1, 0, 0, 0, 0])
den1 = np.array([1, 0.64, 0.7])
den2 = np.array([1, 1.55, 0.7])
den = np.array([1, 2.19, 2.392, 1.533, 0.49])
pretty_print_bicuad_omegayq(num,den1)
pretty_print_bicuad_omegayq(num,den2)

mi_sos = sig.TransferFunction(num1,den)
mi_sos1 = sig.TransferFunction(num,den1)
mi_sos2 = sig.TransferFunction(num,den2)

print (mi_sos)
print (mi_sos1)
print (mi_sos2)
plt.close('all')
analyze_sys(mi_sos, 'mi SOS')
analyze_sys(mi_sos1, 'mi SOS1')
analyze_sys(mi_sos2, 'mi SOS2')
# Out:
# $\displaystyle \frac{s^2 }{s^2 + s \frac{0.8367}{1.307} + 0.8367^2}$
# $\displaystyle \frac{s^2 }{s^2 + s \frac{0.8367}{0.5398} + 0.8367^2}$
# TransferFunctionContinuous(
# array([1., 0., 0., 0., 0.]),
# array([1.   , 2.19 , 2.392, 1.533, 0.49 ]),
# dt: None
# )
# TransferFunctionContinuous(
# array([1., 0., 0.]),
# array([1.  , 0.64, 0.7 ]),
# dt: None
# )
# TransferFunctionContinuous(
# array([1., 0., 0.]),
# array([1.  , 1.55, 0.7 ]),
# dt: None
# )

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
