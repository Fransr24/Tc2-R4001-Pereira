# %% [markdown]
# #  Presentacion de la TS3
# ## Francisco Pereira
#
# ### Ejercicios obligatorios:

# %%
from IPython.display import IFrame
IFrame("Ts3-Final.pdf", width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="Ts3-Final.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import numpy as np
import scipy.signal as sig
import splane as ts3
import matplotlib.pyplot as plt  


ws = 3.5
ee = 10**(1/10)-1
n = 4
amin = 10*np.log10(1+ ee * ws**(2*n))

print ('e^2 = {:f}, n = {:d}, alphamin = {:f}'.format (ee, n, amin))

z,p,k = sig.buttap(n)
num, den = sig.zpk2tf(z,p,k)

num_mp_pb, den_mp_pb = sig.lp2lp (num,den, ee**(-1/2/n))
##convierto a pasa altos
num_mp_pa, den_mp_pa = sig.lp2hp (num_mp_pb,den_mp_pb)

print ('\n tranferencia pasa bajos:\n')
ts3.pretty_print_lti(num_mp_pb,den_mp_pb)
print ('\n tranferencia pasa altos:\n')
ts3.pretty_print_lti(num_mp_pa,den_mp_pa)
print ('\n En 2 SOS:\n')
sos_pa = ts3.tf2sos_analog(num_mp_pa,den_mp_pa)
ts3.pretty_print_SOS(sos_pa)

# %matplotlib qt5
ts3.analyze_sys(sos_pa, 'mi SOS')
# Out:
# e^2 = 0.258925, n = 4, alphamin = 37.657935
#
#  tranferencia pasa bajos:
# $\displaystyle \frac{1.965 }{s^4 + s^3 \,\, 3.094 + s^2 \,\, 4.786 + s \,\, 4.337 + 1.965 }$
#  tranferencia pasa altos:
# $\displaystyle \frac{s^4 }{s^4 + s^3 \,\, 2.207 + s^2 \,\, 2.435 + s \,\, 1.574 + 0.5088 }$
#  En 2 SOS:
# $\displaystyle   \frac{s^2 \,\, 1.41 }{s^2 + s \,\, 1.561 + 0.7133 } . \frac{s^2 \,\, 0.7094 }{s^2 + s \,\, 0.6464 + 0.7133 }$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
