# %% [markdown]
# #  Presentacion de la TS1
# ## Ejercicio 7 del TP1
# ### Francisco Pereira
#
# #### Puntos 1 y 2:

# %% [markdown]
# ![3e76aecb-634a-49ed-bdf3-d09711a67e0b.jpg](attachment:3e76aecb-634a-49ed-bdf3-d09711a67e0b.jpg)

# %% [markdown]
# ![332506e4-b5b4-4ee8-acb2-90f9a21f0265.jpg](attachment:332506e4-b5b4-4ee8-acb2-90f9a21f0265.jpg)

# %% [markdown]
# #### 3):

# %%
import matplotlib.pyplot as plt  
import numpy as np  #
import scipy.signal as sig
from splane import analyze_sys, pretty_print_bicuad_omegayq

w0 = 1
w1 = -1

num = np.array([1, w1])
den = np.array([1, w0])

pretty_print_bicuad_omegayq(num,den)

mi_sos = sig.TransferFunction(num,den)

print (mi_sos)
plt.close('all')
analyze_sys(mi_sos, 'mi SOS')
# Out:
# $\displaystyle \frac{s +  -1 }{s^2 + s \frac{  1}{  1} +   1^2}$
# TransferFunctionContinuous(
# array([ 1., -1.]),
# array([1., 1.]),
# dt: None
# )

# %% [markdown]
# En este punto utilicé la funcion pretty_print_bicuad_omegayq, pero esta me toma los polos como si fueran de 2do oren, por eso en la funcion transferencia me toma como si fuera el denominador de segundo orden, pero son de primer.
