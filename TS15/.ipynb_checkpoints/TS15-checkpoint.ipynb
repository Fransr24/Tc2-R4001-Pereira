# %% [markdown]
# #  Presentacion de la TS15
# ## Francisco Pereira

# %%
from IPython.display import IFrame
IFrame("TS15.pdf", width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="TS15.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Simulacion
# ![image.png](attachment:image.png)
#
# Centro de la banda de paso: Se puede ver que a bajas frecuencias S11 tiende a mas o menos 8bd, y esto es debido al comportamiento del filtro Cheby de orden 4, en w = 0 la transferencia vale un valor menor a 1, y al pasarlo a S11 seguira siendo menor a 1.
#
# Frecuencia de corte: en la frecuencia de corte de la transferencia, el Parametro S11 tiene una atenuacion igual a S21.
#
# Centro de banda de detencion: Durante la transcision irá teniendo picos de subida y bajada debido a la transicion de la transferencia del filtro Chebychev, se cumple que cuando la transferencia es unitaria, S11 es 0. Y en frecuencias tendiendo a infinito, S11 es unitaria, ya que el filtro pasa bajos habrá eliminado la transferencia, haciendo que S11^2 = 1 - S21^2 valga 1
#
# ### Pto 5)
# ![image-2.png](attachment:image-2.png)
