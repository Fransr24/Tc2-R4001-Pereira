# %% [markdown]
# #### Teoria de circuitos 2
# #  Presentacion del Trabajo Practico N°6
# ## Grupo 2
# ### Ejercicio 1
#
# Como no se especifica si la funcion de excitacion es de impedancia o admitancia, opté por impedancia

# %%
from IPython.display import IFrame
IFrame("TP6_1.pdf", width=900, height=900)
# Out:
#         <iframe
#             width="900"
#             height="900"
#             src="TP6_1.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import sympy as sp
import splane as tc2


# Resolución simbólica

s = sp.symbols('s ', complex=True)

# Sea la siguiente función de excitación
Imm = (s**5 + 12*s**3 + 20*s)/(s**6 + 26*s**4+125*s**2+100)

# Implementaremos Imm mediante Foster
k0, koo, ki = tc2.foster(Imm)

# Tratamos a nuestra función imitancia como una Y
tc2.dibujar_foster_derivacion(k0, koo, ki, y_exc = Imm)

# %% [markdown]
# ### Ejercicio 2

# %%
from IPython.display import IFrame
IFrame("TP6_2.pdf", width=900, height=900)
# Out:
#         <iframe
#             width="900"
#             height="900"
#             src="TP6_2.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Ejercicio 3

# %%
from IPython.display import IFrame
IFrame("TP6_3.pdf", width=900, height=900)
# Out:
#         <iframe
#             width="900"
#             height="900"
#             src="TP6_3.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Ejercicio 4

# %%
from IPython.display import IFrame
IFrame("TP6_4.pdf", width=900, height=900)
# Out:
#         <iframe
#             width="900"
#             height="900"
#             src="TP6_4.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
